# %%
import tensorflow as tf
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# 设置随机种子以确保结果可重复
tf.random.set_seed(100)
np.random.seed(100)

# 读取数据
# 请确保 '数据融合--高温合金数据库.xlsx' 文件路径正确
data = pd.read_excel('数据融合--高温合金数据库.xlsx')

# 提取特征和标签
# 假设 'UTS', 'EL', 'TYS', 'RA' 是目标变量
features = data.drop(['UTS', 'EL', 'TYS', 'RA', '合金牌号', '材料', '熔炼工艺'], axis=1)
labels = data[['UTS', 'EL', 'TYS', 'RA']].values

# 对特征进行独热编码（如果有分类变量）
features = pd.get_dummies(features)

# 转换为 NumPy 数组
features = features.values

# 归一化处理
scaler = MinMaxScaler()
features = scaler.fit_transform(features)

# 划分训练集、验证集和测试集
test_ratio = 0.25
validation_ratio = 0.2  # 20% 的数据用于验证集合

# 首先划分训练集和临时集
train_features, temp_features, train_labels, temp_labels = train_test_split(
    features, labels, test_size=(test_ratio + validation_ratio), random_state=100)

# 再将临时集划分为测试集和验证集
test_features, validation_features, test_labels, validation_labels = train_test_split(
    temp_features, temp_labels, 
    test_size=validation_ratio / (test_ratio + validation_ratio),
    random_state=100)

# 构建多目标回归神经网络模型
model_bpnn = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(train_features.shape[1],)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(labels.shape[1])  # 输出层神经元数等于目标变量数
])

# 编译模型
model_bpnn.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])

# 打印模型架构
model_bpnn.summary()

# 定义早停回调以防止过拟合
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 训练模型
history = model_bpnn.fit(
    train_features, train_labels,
    epochs=100,
    batch_size=32,
    validation_data=(validation_features, validation_labels),
    callbacks=[early_stop],
    verbose=1
)

# 预测结果
train_predicted = model_bpnn.predict(train_features)
test_predicted = model_bpnn.predict(test_features)
validation_predicted = model_bpnn.predict(validation_features)

# 计算性能指标
def compute_metrics(true, predicted):
    rmse = np.sqrt(mean_squared_error(true, predicted, multioutput='raw_values'))
    r2 = r2_score(true, predicted, multioutput='raw_values')
    return rmse, r2

# 定义目标变量列表
target_names = ['UTS', 'EL', 'TYS', 'RA']
metrics = {}

for i, target in enumerate(target_names):
    metrics[target] = {}
    # 训练集
    rmse_tr, r2_tr = compute_metrics(train_labels[:, i], train_predicted[:, i])
    metrics[target]['Train_RMSE'] = rmse_tr
    metrics[target]['Train_R2'] = r2_tr
    # 测试集
    rmse_te, r2_te = compute_metrics(test_labels[:, i], test_predicted[:, i])
    metrics[target]['Test_RMSE'] = rmse_te
    metrics[target]['Test_R2'] = r2_te
    # 验证集
    rmse_val, r2_val = compute_metrics(validation_labels[:, i], validation_predicted[:, i])
    metrics[target]['Validation_RMSE'] = rmse_val
    metrics[target]['Validation_R2'] = r2_val

# 输出性能指标
for target in target_names:
    print(f"=== {target} Performance ===")
    print(f"RMSE (Train): {metrics[target]['Train_RMSE']:.2f}")
    print(f"RMSE (Test): {metrics[target]['Test_RMSE']:.2f}")
    print(f"RMSE (Validation): {metrics[target]['Validation_RMSE']:.2f}")
    print(f"R^2 (Train): {metrics[target]['Train_R2']:.2f}")
    print(f"R^2 (Test): {metrics[target]['Test_R2']:.2f}")
    print(f"R^2 (Validation): {metrics[target]['Validation_R2']:.2f}\n")

# 绘制训练过程中的损失函数变化
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Model Loss During Training')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.show()

# 设置绘图参数
plt.rcParams['figure.figsize'] = (20, 15)
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300

# 创建子图
fig, axes = plt.subplots(2, 2, figsize=(20, 15))
axes = axes.flatten()

for i, target in enumerate(target_names):
    ax = axes[i]
    ax.set_facecolor("white")
    ax.grid(True, linestyle=':', linewidth=0.9, alpha=0.8)
    for spine in ax.spines.values():
        spine.set_linewidth(1.5)
        spine.set_color('black')
    
    # 确定坐标轴范围
    max_val = max(
        np.max(labels[:, i]),
        np.max([train_predicted[:, i], test_predicted[:, i], validation_predicted[:, i]])) * 1.05
    ax.set_xticks(np.linspace(0, max_val, 11))
    ax.set_yticks(np.linspace(0, max_val, 11))
    
    # 绘制散点
    ax.scatter(train_labels[:, i], train_predicted[:, i], alpha=0.7, s=33, linewidths=0.4, c='#85a2d2',
               edgecolor='#000000', label=f'Training set (R²={metrics[target]["Train_R2"]:.2f})', marker='o')
    ax.scatter(test_labels[:, i], test_predicted[:, i], alpha=0.7, s=33, linewidths=0.4, c='#c2acda',
               edgecolor='#000000', label=f'Testing set (R²={metrics[target]["Test_R2"]:.2f})', marker='o')
    ax.scatter(validation_labels[:, i], validation_predicted[:, i], alpha=0.7, s=33, linewidths=0.4, c='#c0db82',
               edgecolor='#000000', label=f'Validation set (R²={metrics[target]["Validation_R2"]:.2f})', marker='o')
    
    # 绘制参考线
    ax.plot([0, max_val], [0, max_val], 'b--', linewidth=0.8, alpha=0.8)
    ax.set_xlim(0, max_val)
    ax.set_ylim(0, max_val)
    
    # 设置标签和标题
    ax.set_xlabel(f'Real {target}', fontsize=16, weight='bold', labelpad=20, fontname='Times New Roman')
    ax.set_ylabel(f'Predicted {target}', fontsize=16, weight='bold', labelpad=20, fontname='Times New Roman')
    ax.set_title(f'{target}: Real vs Predicted', fontsize=18, weight='bold', fontname='Times New Roman')
    
    # 设置图例
    ax.legend(prop={'family': 'Times New Roman', 'weight': 'bold', 'size': 12}, loc='upper left')

# 添加整体标题
plt.suptitle('Multi-Objective Neural Network Regressor: Real vs Predicted for UTS, EL, TYS, and RA', fontsize=22, weight='bold', fontname='Times New Roman')

# 调整布局
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# 显示图形
plt.show()
# Out:
# 2024-12-25 11:06:55.310999: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/macbookpro/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/macbookpro/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               2176
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 19204 (75.02 KB)
# Trainable params: 19204 (75.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 18/18 [==============================] - 3s 48ms/step - loss: 414793.9375 - mean_squared_error: 414793.9375 - val_loss: 404107.4062 - val_mean_squared_error: 404107.4062
# Epoch 2/100
# 18/18 [==============================] - 0s 7ms/step - loss: 412086.9688 - mean_squared_error: 412086.9688 - val_loss: 399289.6875 - val_mean_squared_error: 399289.6875
# Epoch 3/100
# 18/18 [==============================] - 0s 5ms/step - loss: 403724.9375 - mean_squared_error: 403724.9375 - val_loss: 385712.5000 - val_mean_squared_error: 385712.5000
# Epoch 4/100
# 18/18 [==============================] - 0s 6ms/step - loss: 382993.9062 - mean_squared_error: 382993.9062 - val_loss: 356169.9688 - val_mean_squared_error: 356169.9688
# Epoch 5/100
# 18/18 [==============================] - 0s 7ms/step - loss: 343028.2188 - mean_squared_error: 343028.2188 - val_loss: 304422.9375 - val_mean_squared_error: 304422.9375
# Epoch 6/100
# 18/18 [==============================] - 0s 12ms/step - loss: 280121.8125 - mean_squared_error: 280121.8125 - val_loss: 230488.5938 - val_mean_squared_error: 230488.5938
# Epoch 7/100
# 18/18 [==============================] - 0s 12ms/step - loss: 199912.6875 - mean_squared_error: 199912.6875 - val_loss: 149033.9062 - val_mean_squared_error: 149033.9062
# Epoch 8/100
# 18/18 [==============================] - 0s 10ms/step - loss: 123266.3359 - mean_squared_error: 123266.3359 - val_loss: 86750.2266 - val_mean_squared_error: 86750.2266
# Epoch 9/100
# 18/18 [==============================] - 0s 6ms/step - loss: 76586.0000 - mean_squared_error: 76586.0000 - val_loss: 60096.3203 - val_mean_squared_error: 60096.3203
# Epoch 10/100
# 18/18 [==============================] - 0s 5ms/step - loss: 62717.7969 - mean_squared_error: 62717.7969 - val_loss: 55026.2148 - val_mean_squared_error: 55026.2148
# Epoch 11/100
# 18/18 [==============================] - 0s 5ms/step - loss: 59919.8711 - mean_squared_error: 59919.8711 - val_loss: 52964.5312 - val_mean_squared_error: 52964.5312
# Epoch 12/100
# 18/18 [==============================] - 0s 4ms/step - loss: 57702.9336 - mean_squared_error: 57702.9336 - val_loss: 51361.6367 - val_mean_squared_error: 51361.6367
# Epoch 13/100
# 18/18 [==============================] - 0s 5ms/step - loss: 55873.4883 - mean_squared_error: 55873.4883 - val_loss: 50184.6094 - val_mean_squared_error: 50184.6094
# Epoch 14/100
# 18/18 [==============================] - 0s 5ms/step - loss: 54521.7773 - mean_squared_error: 54521.7773 - val_loss: 49113.0430 - val_mean_squared_error: 49113.0430
# Epoch 15/100
# 18/18 [==============================] - 0s 5ms/step - loss: 53262.0312 - mean_squared_error: 53262.0312 - val_loss: 48140.2812 - val_mean_squared_error: 48140.2812
# Epoch 16/100
# 18/18 [==============================] - 0s 5ms/step - loss: 51954.6211 - mean_squared_error: 51954.6211 - val_loss: 47200.4844 - val_mean_squared_error: 47200.4844
# Epoch 17/100
# 18/18 [==============================] - 0s 4ms/step - loss: 50832.1367 - mean_squared_error: 50832.1367 - val_loss: 46265.9961 - val_mean_squared_error: 46265.9961
# Epoch 18/100
# 18/18 [==============================] - 0s 4ms/step - loss: 49751.0820 - mean_squared_error: 49751.0820 - val_loss: 45444.0625 - val_mean_squared_error: 45444.0625
# Epoch 19/100
# 18/18 [==============================] - 0s 15ms/step - loss: 48591.1914 - mean_squared_error: 48591.1914 - val_loss: 44579.7461 - val_mean_squared_error: 44579.7461
# Epoch 20/100
# 18/18 [==============================] - 0s 23ms/step - loss: 47610.3047 - mean_squared_error: 47610.3047 - val_loss: 43784.3633 - val_mean_squared_error: 43784.3633
# Epoch 21/100
# 18/18 [==============================] - 0s 13ms/step - loss: 46679.1758 - mean_squared_error: 46679.1758 - val_loss: 42972.3047 - val_mean_squared_error: 42972.3047
# Epoch 22/100
# 18/18 [==============================] - 0s 6ms/step - loss: 45720.3477 - mean_squared_error: 45720.3477 - val_loss: 42332.7266 - val_mean_squared_error: 42332.7266
# Epoch 23/100
# 18/18 [==============================] - 0s 4ms/step - loss: 44734.7539 - mean_squared_error: 44734.7539 - val_loss: 41477.8242 - val_mean_squared_error: 41477.8242
# Epoch 24/100
# 18/18 [==============================] - 0s 5ms/step - loss: 43757.2031 - mean_squared_error: 43757.2031 - val_loss: 40842.2812 - val_mean_squared_error: 40842.2812
# Epoch 25/100
# 18/18 [==============================] - 0s 4ms/step - loss: 42876.3320 - mean_squared_error: 42876.3320 - val_loss: 40113.6680 - val_mean_squared_error: 40113.6680
# Epoch 26/100
# 18/18 [==============================] - 0s 4ms/step - loss: 42049.2031 - mean_squared_error: 42049.2031 - val_loss: 39456.6289 - val_mean_squared_error: 39456.6289
# Epoch 27/100
# 18/18 [==============================] - 0s 9ms/step - loss: 41155.3281 - mean_squared_error: 41155.3281 - val_loss: 38818.3047 - val_mean_squared_error: 38818.3047
# Epoch 28/100
# 18/18 [==============================] - 0s 4ms/step - loss: 40403.2734 - mean_squared_error: 40403.2734 - val_loss: 38140.6719 - val_mean_squared_error: 38140.6719
# Epoch 29/100
# 18/18 [==============================] - 0s 4ms/step - loss: 39569.8164 - mean_squared_error: 39569.8164 - val_loss: 37576.5508 - val_mean_squared_error: 37576.5508
# Epoch 30/100
# 18/18 [==============================] - 0s 4ms/step - loss: 38674.9883 - mean_squared_error: 38674.9883 - val_loss: 36833.3047 - val_mean_squared_error: 36833.3047
# Epoch 31/100
# 18/18 [==============================] - 0s 4ms/step - loss: 37992.4609 - mean_squared_error: 37992.4609 - val_loss: 36194.7148 - val_mean_squared_error: 36194.7148
# Epoch 32/100
# 18/18 [==============================] - 0s 4ms/step - loss: 37229.0625 - mean_squared_error: 37229.0625 - val_loss: 35689.2344 - val_mean_squared_error: 35689.2344
# Epoch 33/100
# 18/18 [==============================] - 0s 4ms/step - loss: 36492.5820 - mean_squared_error: 36492.5820 - val_loss: 35116.4062 - val_mean_squared_error: 35116.4062
# Epoch 34/100
# 18/18 [==============================] - 0s 4ms/step - loss: 35768.0664 - mean_squared_error: 35768.0664 - val_loss: 34483.4258 - val_mean_squared_error: 34483.4258
# Epoch 35/100
# 18/18 [==============================] - 0s 4ms/step - loss: 35075.3672 - mean_squared_error: 35075.3672 - val_loss: 34071.4375 - val_mean_squared_error: 34071.4375
# Epoch 36/100
# 18/18 [==============================] - 0s 4ms/step - loss: 34439.6953 - mean_squared_error: 34439.6953 - val_loss: 33338.2578 - val_mean_squared_error: 33338.2578
# Epoch 37/100
# 18/18 [==============================] - 0s 4ms/step - loss: 33653.5273 - mean_squared_error: 33653.5273 - val_loss: 32845.1875 - val_mean_squared_error: 32845.1875
# Epoch 38/100
# 18/18 [==============================] - 0s 5ms/step - loss: 33023.5664 - mean_squared_error: 33023.5664 - val_loss: 32415.4434 - val_mean_squared_error: 32415.4434
# Epoch 39/100
# 18/18 [==============================] - 0s 4ms/step - loss: 32341.0938 - mean_squared_error: 32341.0938 - val_loss: 31835.3535 - val_mean_squared_error: 31835.3535
# Epoch 40/100
# 18/18 [==============================] - 0s 4ms/step - loss: 31741.6035 - mean_squared_error: 31741.6035 - val_loss: 31340.6406 - val_mean_squared_error: 31340.6406
# Epoch 41/100
# 18/18 [==============================] - 0s 4ms/step - loss: 31153.0918 - mean_squared_error: 31153.0918 - val_loss: 30857.6523 - val_mean_squared_error: 30857.6523
# Epoch 42/100
# 18/18 [==============================] - 0s 4ms/step - loss: 30574.7168 - mean_squared_error: 30574.7168 - val_loss: 30551.3457 - val_mean_squared_error: 30551.3457
# Epoch 43/100
# 18/18 [==============================] - 0s 4ms/step - loss: 30048.9082 - mean_squared_error: 30048.9082 - val_loss: 30110.3379 - val_mean_squared_error: 30110.3379
# Epoch 44/100
# 18/18 [==============================] - 0s 4ms/step - loss: 29517.3203 - mean_squared_error: 29517.3203 - val_loss: 29610.7441 - val_mean_squared_error: 29610.7441
# Epoch 45/100
# 18/18 [==============================] - 0s 4ms/step - loss: 28958.6699 - mean_squared_error: 28958.6699 - val_loss: 29270.3359 - val_mean_squared_error: 29270.3359
# Epoch 46/100
# 18/18 [==============================] - 0s 4ms/step - loss: 28494.0898 - mean_squared_error: 28494.0898 - val_loss: 28841.4238 - val_mean_squared_error: 28841.4238
# Epoch 47/100
# 18/18 [==============================] - 0s 4ms/step - loss: 28068.2168 - mean_squared_error: 28068.2168 - val_loss: 28480.2344 - val_mean_squared_error: 28480.2344
# Epoch 48/100
# 18/18 [==============================] - 0s 4ms/step - loss: 27605.2598 - mean_squared_error: 27605.2598 - val_loss: 28171.8965 - val_mean_squared_error: 28171.8965
# Epoch 49/100
# 18/18 [==============================] - 0s 4ms/step - loss: 27197.6465 - mean_squared_error: 27197.6465 - val_loss: 27865.9688 - val_mean_squared_error: 27865.9688
# Epoch 50/100
# 18/18 [==============================] - 0s 4ms/step - loss: 26860.0293 - mean_squared_error: 26860.0293 - val_loss: 27653.3105 - val_mean_squared_error: 27653.3105
# Epoch 51/100
# 18/18 [==============================] - 0s 4ms/step - loss: 26465.4980 - mean_squared_error: 26465.4980 - val_loss: 27316.8438 - val_mean_squared_error: 27316.8438
# Epoch 52/100
# 18/18 [==============================] - 0s 4ms/step - loss: 26179.5059 - mean_squared_error: 26179.5059 - val_loss: 27147.9141 - val_mean_squared_error: 27147.9141
# Epoch 53/100
# 18/18 [==============================] - 0s 4ms/step - loss: 25853.6348 - mean_squared_error: 25853.6348 - val_loss: 26895.0312 - val_mean_squared_error: 26895.0312
# Epoch 54/100
# 18/18 [==============================] - 0s 4ms/step - loss: 25591.6152 - mean_squared_error: 25591.6152 - val_loss: 26769.9727 - val_mean_squared_error: 26769.9727
# Epoch 55/100
# 18/18 [==============================] - 0s 4ms/step - loss: 25429.3223 - mean_squared_error: 25429.3223 - val_loss: 26548.4355 - val_mean_squared_error: 26548.4355
# Epoch 56/100
# 18/18 [==============================] - 0s 4ms/step - loss: 25077.8867 - mean_squared_error: 25077.8867 - val_loss: 26480.8301 - val_mean_squared_error: 26480.8301
# Epoch 57/100
# 18/18 [==============================] - 0s 4ms/step - loss: 24863.5469 - mean_squared_error: 24863.5469 - val_loss: 26242.8340 - val_mean_squared_error: 26242.8340
# Epoch 58/100
# 18/18 [==============================] - 0s 4ms/step - loss: 24665.2344 - mean_squared_error: 24665.2344 - val_loss: 25991.5566 - val_mean_squared_error: 25991.5566
# Epoch 59/100
# 18/18 [==============================] - 0s 4ms/step - loss: 24472.3945 - mean_squared_error: 24472.3945 - val_loss: 25990.4531 - val_mean_squared_error: 25990.4531
# Epoch 60/100
# 18/18 [==============================] - 0s 4ms/step - loss: 24308.2598 - mean_squared_error: 24308.2598 - val_loss: 25950.2285 - val_mean_squared_error: 25950.2285
# Epoch 61/100
# 18/18 [==============================] - 0s 4ms/step - loss: 24154.4785 - mean_squared_error: 24154.4785 - val_loss: 25675.3574 - val_mean_squared_error: 25675.3574
# Epoch 62/100
# 18/18 [==============================] - 0s 4ms/step - loss: 24013.5293 - mean_squared_error: 24013.5293 - val_loss: 25786.7031 - val_mean_squared_error: 25786.7031
# Epoch 63/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23860.4570 - mean_squared_error: 23860.4570 - val_loss: 25487.2812 - val_mean_squared_error: 25487.2812
# Epoch 64/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23753.1406 - mean_squared_error: 23753.1406 - val_loss: 25611.2773 - val_mean_squared_error: 25611.2773
# Epoch 65/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23701.3418 - mean_squared_error: 23701.3418 - val_loss: 25406.0605 - val_mean_squared_error: 25406.0605
# Epoch 66/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23619.2754 - mean_squared_error: 23619.2754 - val_loss: 25528.4688 - val_mean_squared_error: 25528.4688
# Epoch 67/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23467.6191 - mean_squared_error: 23467.6191 - val_loss: 25196.0859 - val_mean_squared_error: 25196.0859
# Epoch 68/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23392.5547 - mean_squared_error: 23392.5547 - val_loss: 25390.2383 - val_mean_squared_error: 25390.2383
# Epoch 69/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23314.4453 - mean_squared_error: 23314.4453 - val_loss: 25140.6562 - val_mean_squared_error: 25140.6562
# Epoch 70/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23251.2578 - mean_squared_error: 23251.2578 - val_loss: 25139.2012 - val_mean_squared_error: 25139.2012
# Epoch 71/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23189.0820 - mean_squared_error: 23189.0820 - val_loss: 25253.1172 - val_mean_squared_error: 25253.1172
# Epoch 72/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23094.5176 - mean_squared_error: 23094.5176 - val_loss: 25027.4258 - val_mean_squared_error: 25027.4258
# Epoch 73/100
# 18/18 [==============================] - 0s 4ms/step - loss: 23001.1738 - mean_squared_error: 23001.1738 - val_loss: 25141.9023 - val_mean_squared_error: 25141.9023
# Epoch 74/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22928.4219 - mean_squared_error: 22928.4219 - val_loss: 25026.8906 - val_mean_squared_error: 25026.8906
# Epoch 75/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22869.8535 - mean_squared_error: 22869.8535 - val_loss: 25010.0371 - val_mean_squared_error: 25010.0371
# Epoch 76/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22803.6973 - mean_squared_error: 22803.6973 - val_loss: 24973.0293 - val_mean_squared_error: 24973.0293
# Epoch 77/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22772.1562 - mean_squared_error: 22772.1562 - val_loss: 24821.4453 - val_mean_squared_error: 24821.4453
# Epoch 78/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22799.9531 - mean_squared_error: 22799.9531 - val_loss: 24861.9434 - val_mean_squared_error: 24861.9434
# Epoch 79/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22648.1074 - mean_squared_error: 22648.1074 - val_loss: 24830.2383 - val_mean_squared_error: 24830.2383
# Epoch 80/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22594.8262 - mean_squared_error: 22594.8262 - val_loss: 24829.9746 - val_mean_squared_error: 24829.9746
# Epoch 81/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22525.3984 - mean_squared_error: 22525.3984 - val_loss: 24753.2695 - val_mean_squared_error: 24753.2695
# Epoch 82/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22520.3809 - mean_squared_error: 22520.3809 - val_loss: 24678.3340 - val_mean_squared_error: 24678.3340
# Epoch 83/100
# 18/18 [==============================] - 0s 5ms/step - loss: 22404.4707 - mean_squared_error: 22404.4707 - val_loss: 24850.3379 - val_mean_squared_error: 24850.3379
# Epoch 84/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22410.7051 - mean_squared_error: 22410.7051 - val_loss: 24597.8457 - val_mean_squared_error: 24597.8457
# Epoch 85/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22374.9805 - mean_squared_error: 22374.9805 - val_loss: 24615.9551 - val_mean_squared_error: 24615.9551
# Epoch 86/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22339.2773 - mean_squared_error: 22339.2773 - val_loss: 24587.3105 - val_mean_squared_error: 24587.3105
# Epoch 87/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22313.8555 - mean_squared_error: 22313.8555 - val_loss: 24511.8555 - val_mean_squared_error: 24511.8555
# Epoch 88/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22415.6836 - mean_squared_error: 22415.6836 - val_loss: 24535.3535 - val_mean_squared_error: 24535.3535
# Epoch 89/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22236.6191 - mean_squared_error: 22236.6191 - val_loss: 24396.7090 - val_mean_squared_error: 24396.7090
# Epoch 90/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22164.3535 - mean_squared_error: 22164.3535 - val_loss: 24637.0840 - val_mean_squared_error: 24637.0840
# Epoch 91/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22054.0488 - mean_squared_error: 22054.0488 - val_loss: 24414.0957 - val_mean_squared_error: 24414.0957
# Epoch 92/100
# 18/18 [==============================] - 0s 4ms/step - loss: 22017.5723 - mean_squared_error: 22017.5723 - val_loss: 24420.3281 - val_mean_squared_error: 24420.3281
# Epoch 93/100
# 18/18 [==============================] - 0s 4ms/step - loss: 21982.1543 - mean_squared_error: 21982.1543 - val_loss: 24356.7852 - val_mean_squared_error: 24356.7852
# Epoch 94/100
# 18/18 [==============================] - 0s 4ms/step - loss: 21957.1562 - mean_squared_error: 21957.1562 - val_loss: 24283.0938 - val_mean_squared_error: 24283.0938
# Epoch 95/100
# 18/18 [==============================] - 0s 4ms/step - loss: 21905.3184 - mean_squared_error: 21905.3184 - val_loss: 24363.6562 - val_mean_squared_error: 24363.6562
# Epoch 96/100
# 18/18 [==============================] - 0s 4ms/step - loss: 21868.5254 - mean_squared_error: 21868.5254 - val_loss: 24187.9785 - val_mean_squared_error: 24187.9785
# Epoch 97/100
# 18/18 [==============================] - 0s 4ms/step - loss: 21794.8008 - mean_squared_error: 21794.8008 - val_loss: 24315.0586 - val_mean_squared_error: 24315.0586
# Epoch 98/100
# 18/18 [==============================] - 0s 4ms/step - loss: 21809.8477 - mean_squared_error: 21809.8477 - val_loss: 24273.0684 - val_mean_squared_error: 24273.0684
# Epoch 99/100
# 18/18 [==============================] - 0s 4ms/step - loss: 21775.6230 - mean_squared_error: 21775.6230 - val_loss: 24143.2305 - val_mean_squared_error: 24143.2305
# Epoch 100/100
# 18/18 [==============================] - 0s 4ms/step - loss: 21849.3789 - mean_squared_error: 21849.3789 - val_loss: 24266.7051 - val_mean_squared_error: 24266.7051
# 18/18 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# === UTS Performance ===
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/sy/gl301n8s5pl2fptdx8bcns5h0000gn/T/ipykernel_81694/3393441586.py in <module>
#     103 for target in target_names:
#     104     print(f"=== {target} Performance ===")
# --> 105     print(f"RMSE (Train): {metrics[target]['Train_RMSE']:.2f}")
#     106     print(f"RMSE (Test): {metrics[target]['Test_RMSE']:.2f}")
#     107     print(f"RMSE (Validation): {metrics[target]['Validation_RMSE']:.2f}")
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__
